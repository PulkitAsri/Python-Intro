# %% [markdown]
# ## AIM WHAT TO DO ?

# %%
# Import Statements
import cv2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
# plt.imread("./pokemonImages/result.jpg")

# %%
img1 = plt.imread("./pokemonImages/img1.jpg")
img2 = plt.imread("./pokemonImages/img2.jpg")
img3 = plt.imread("./pokemonImages/img3.jpg")
img4 = plt.imread("./pokemonImages/img4.jpg")
img5 = plt.imread("./pokemonImages/img5.jpeg")

# %%
img1 = cv2.resize(img1,(200,200))
img2 = cv2.resize(img2,(200,200))
img3 = cv2.resize(img3,(200,200))
img4 = cv2.resize(img4,(200,200))
img5 = cv2.resize(img5,(100,100))

# %%
result=np.zeros((430,430,3),dtype="uint8")

# %%
plt.imshow(result)
plt.show()

# %%
result[10:210,10:210,:]=img1
result[10:210,220:-10,:]=img2
result[220:-10,10:210,:]=img3
result[220:-10,220:-10,:]=img4

# %%
plt.imshow(result)
plt.show()

# %%
plt.imshow(img5)
plt.show()

# %%
centreImage=np.zeros((110,110,3),dtype="uint8")

# %%
plt.imshow(centreImage)
plt.show()

# %%
centreImage[5:-5,5:-5,:]=img5

# %%
plt.imshow(centreImage)
plt.show()

# %%
result[result.shape[0]//2 - centreImage.shape[0]//2 :result.shape[0]//2 + centreImage.shape[0]//2,result.shape[1]//2 - centreImage.shape[1]//2 :result.shape[1]//2 + centreImage.shape[1]//2]= centreImage

# %%
plt.imshow(result)
plt.show()
